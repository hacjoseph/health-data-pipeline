# %% [markdown]
# # Lecture du fichier

# %%
import pandas as pd

# %%
df = pd.read_csv("effectifs.csv", sep=";")

# %% [markdown]
# Affichage des 10 premières lignes

# %%
df.head()
# Out:
#    annee               patho_niv1             patho_niv2  \
# 0   2020  Maladies psychiatriques  Troubles psychotiques
# 1   2020  Maladies psychiatriques  Troubles psychotiques
# 2   2020  Maladies psychiatriques  Troubles psychotiques
# 3   2020  Maladies psychiatriques  Troubles psychotiques
# 4   2020  Maladies psychiatriques  Troubles psychotiques
#
#               patho_niv3          top cla_age_5  sexe  region dept   Ntop  \
# 0  Troubles psychotiques  PSY_PSC_IND     50-54     2       1  971  280.0
# 1  Troubles psychotiques  PSY_PSC_IND     50-54     2       3  999   50.0
# 2  Troubles psychotiques  PSY_PSC_IND     50-54     2       4  974  390.0
# 3  Troubles psychotiques  PSY_PSC_IND     50-54     2      11   77  350.0
# 4  Troubles psychotiques  PSY_PSC_IND     50-54     2      11   91  400.0
#
#     Npop   prev Niveau prioritaire libelle_classe_age libelle_sexe   tri
# 0  17040  1.643                2,3     de 50 à 54 ans       femmes  48.0
# ...

# %% [markdown]
# nombre de lignes et de collonnes

# %%
nb_lignes, nb_colonnes = df.shape
print(f"Le DataFrame contient {nb_lignes} \n lignes et {nb_colonnes} colonnes.")
# Out:
# Le DataFrame contient 5796000
#  lignes et 16 colonnes.

# %% [markdown]
# ## Je veux voir combien d'années différente j'ai dans le fichier

# %%
df["annee"].value_counts().sort_index()
# Out:
# annee
# 2015    579600
# 2016    579600
# 2017    579600
# 2018    579600
# 2019    579600
# 2020    579600
# 2021    579600
# 2022    579600
# 2023    579600
# 2024    579600
# Name: count, dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['annee', 'patho_niv1', 'patho_niv2', 'patho_niv3', 'top', 'cla_age_5', 'sexe', 'region', 'dept', 'Ntop', 'Npop', 'prev', 'Niveau prioritaire', 'libelle_classe_age', 'libelle_sexe', 'tri']
